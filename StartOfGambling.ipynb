# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/vagnerbattles/DevOps/Gambling/E0.csv')

# %%
data
# Out:
#     Div        Date   Time        HomeTeam          AwayTeam  FTHG  FTAG FTR  \
# 0    E0  09/08/2019  20:00       Liverpool           Norwich     4     1   H
# 1    E0  10/08/2019  12:30        West Ham          Man City     0     5   A
# 2    E0  10/08/2019  15:00     Bournemouth  Sheffield United     1     1   D
# 3    E0  10/08/2019  15:00         Burnley       Southampton     3     0   H
# 4    E0  10/08/2019  15:00  Crystal Palace           Everton     0     0   D
# ..   ..         ...    ...             ...               ...   ...   ...  ..
# 375  E0  26/07/2020  16:00       Leicester        Man United     0     2   A
# 376  E0  26/07/2020  16:00        Man City           Norwich     5     0   H
# 377  E0  26/07/2020  16:00       Newcastle         Liverpool     1     3   A
# 378  E0  26/07/2020  16:00     Southampton  Sheffield United     3     1   H
# 379  E0  26/07/2020  16:00        West Ham       Aston Villa     1     1   D
#
# ...

# %% [markdown]
# ## Работа на день
#
# Смотрим описание столбцов по данным на сайте, которое указано в предисловии к проекту. Выбираем стратегию, которую думаем стоит протестировать по данным, пример будет ниже.

# %%
#Создаем колонку всего голов в данных

data['FTG'] = data['FTHG']+data['FTAG']

data['FTG'].value_counts()
# Out:
# 2    106
# 3     91
# 4     63
# 1     55
# 5     33
# 0     21
# 7      4
# 6      4
# 8      2
# 9      1
# Name: FTG, dtype: int64

# %% [raw]
# Видим то, что всего в 21 матче из 380 было 0 голов за матч. Можно поисследовать почему и какая причина была таких сухих матчей. Не исследуем матчи где голов больше или равно 5, будем равнять их к 5 голам за матч.
